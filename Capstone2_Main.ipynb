# %%
import pandas as pd

data = pd.read_csv('CAPSTONE2.csv', usecols=lambda column: column not in ['Unnamed: 14'])

# %%
data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP Attendance  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26     41,423
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24     74,864
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97     59,927
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84     35,794
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76     45,470
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...        ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02     14,991
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96     13,636
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87      9,880
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70     14,000
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67     17,765
#
#           Year League
# ...

# %%
print(data.dtypes)
# Out:
# Rk              int64
# Squad          object
# MP              int64
# W               int64
# D               int64
# L               int64
# GF              int64
# GA              int64
# GD              int64
# Pts             int64
# Pts/MP        float64
# Attendance     object
# Year           object
# League         object
# dtype: object

# %%
data["Attendance"] = data["Attendance"].str.replace(",", "").astype(int)

# %%
# Filter the data to only show Premier League (PL) teams
pl_data = data[data['League'].str.contains('PL')]

# Calculate the average attendance for PL teams
average_attendance_pl = pl_data['Attendance'].mean()

print(f"Average attendance for Premier League teams: {average_attendance_pl:.2f}")
# Out:
# Average attendance for Premier League teams: 36144.25

# %%
# Filter the data to only show Premier League (PL) teams
pl_data = data[data['League'].str.contains('CS')]

# Calculate the average attendance for PL teams
average_attendance_pl = pl_data['Attendance'].mean()

print(f"Average attendance for Championship teams: {average_attendance_pl:.2f}")
# Out:
# Average attendance for Championship teams: 18327.26

# %%
import matplotlib.pyplot as plt

# Define the data
average_attendance_pl = 36144.25
average_attendance_cs = 18327.26

# Create a bar chart comparing the average attendance in PL and CS
fig, ax = plt.subplots()
ax.bar(['Premier League', 'Championship'], [average_attendance_pl, average_attendance_cs])
ax.set_ylabel('Average Attendance')
ax.set_title('Comparison of Average Attendance in PL and CS')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Filter the data to only show Premier League (PL) teams
pl_data = data[data['League'].str.contains('PL')]

# Calculate the average attendance for PL teams per year
average_attendance_pl = pl_data.groupby('Year')['Attendance'].mean()

# Create a bar chart of the average attendance per year
fig, ax = plt.subplots(figsize=(12, 8))
ax.bar(average_attendance_pl.index, average_attendance_pl.values)
ax.set_xlabel('Season')
ax.set_ylabel('Average Attendance')
ax.set_title('Average Attendance for Premier League Teams (per season)')
plt.show()

# %%
# Filter the data to only show Championship (CS) teams
cs_data = data[data['League'].str.contains('CS')]

# Group the data by year and calculate the mean attendance for each year
cs_yearly_attendance = cs_data.groupby('Year')['Attendance'].mean()

# Create a bar chart of the average attendance per season for the CS
plt.figure(figsize=(10, 6))
plt.bar(cs_yearly_attendance.index, cs_yearly_attendance.values, color='green')
plt.title('Average Attendance per Season for the Championship')
plt.xlabel('Season')
plt.ylabel('Average Attendance')
plt.xticks(rotation=45)
plt.show()

# %%
data['Attendance'] = data['Attendance'].astype(str)

# %%
import matplotlib.pyplot as plt

# Filter the data to only show Premier League (PL) teams
pl_data = data[data['League'].str.contains('PL')]

# Convert the Attendance column to int
pl_data['Attendance'] = pl_data['Attendance'].str.replace(',', '').astype(int)

# Group the data by Squad and calculate the mean attendance for each team
team_attendance = pl_data.groupby('Squad')['Attendance'].mean().sort_values(ascending=False)

# Take the top 5 teams with highest attendance
top_5_teams = team_attendance[:5]

# Create a horizontal bar chart
plt.figure(figsize=(10,5))
plt.barh(top_5_teams.index, top_5_teams.values)
plt.xlabel('Average Attendance')
plt.title('Top 5 Premier League Teams with Highest Attendance')
plt.show()
# Out:
# <ipython-input-115-b788de22331a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pl_data['Attendance'] = pl_data['Attendance'].str.replace(',', '').astype(int)

# %%
data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP Attendance  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26      41423
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24      74864
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97      59927
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84      35794
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76      45470
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...        ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02      14991
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96      13636
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87       9880
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70      14000
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67      17765
#
#           Year League
# ...

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2009/10'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2010/11'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Newcastle Utd
# 1        West Brom
# 2        Blackpool
# Name: Squad, dtype: object

# %%
data['Attendance'] = data['Attendance'].astype(int)

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2009/10', '2010/11']) & 
                     data['Squad'].isin(['Newcastle Utd', 'West Brom', 'Blackpool'])]

# Extract the attendance data for each team and season
newcastle_attendance = relevant_data[(relevant_data['Squad'] == 'Newcastle Utd')]['Attendance'].tolist()
west_brom_attendance = relevant_data[(relevant_data['Squad'] == 'West Brom')]['Attendance'].tolist()
blackpool_attendance = relevant_data[(relevant_data['Squad'] == 'Blackpool')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
newcastle_percent_change = ((newcastle_attendance[1] - newcastle_attendance[0]) / newcastle_attendance[0]) * 100
west_brom_percent_change = ((west_brom_attendance[1] - west_brom_attendance[0]) / west_brom_attendance[0]) * 100
blackpool_percent_change = ((blackpool_attendance[1] - blackpool_attendance[0]) / blackpool_attendance[0]) * 100

# Print the attendance data and percentage change for each team
print(f"Newcastle Utd attendance: {newcastle_attendance} ({newcastle_percent_change:.2f}%)")
print(f"West Brom attendance: {west_brom_attendance} ({west_brom_percent_change:.2f}%)")
print(f"Blackpool attendance: {blackpool_attendance} ({blackpool_percent_change:.2f}%)")
# Out:
# Newcastle Utd attendance: [43388, 47718] (9.98%)
# West Brom attendance: [22199, 24683] (11.19%)
# Blackpool attendance: [8611, 15775] (83.20%)

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2010/11'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2011/12'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0             QPR
# 1    Norwich City
# 2    Swansea City
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2010/11', '2011/12']) & 
                     data['Squad'].isin(['QPR', 'Norwich City', 'Swansea City'])]

# Extract the attendance data for each team and season
qpr_attendance = relevant_data[(relevant_data['Squad'] == 'QPR')]['Attendance'].tolist()
norwich_attendance = relevant_data[(relevant_data['Squad'] == 'Norwich City')]['Attendance'].tolist()
swansea_attendance = relevant_data[(relevant_data['Squad'] == 'Swansea City')]['Attendance'].tolist()

# Calculate the percentage change in attendance from the first to the second season for each team
qpr_pct_change = ((qpr_attendance[1] - qpr_attendance[0]) / qpr_attendance[0]) * 100
norwich_pct_change = ((norwich_attendance[1] - norwich_attendance[0]) / norwich_attendance[0]) * 100
swansea_pct_change = ((swansea_attendance[1] - swansea_attendance[0]) / swansea_attendance[0]) * 100

# Print the attendance data and percentage change for each team
print(f"QPR attendance: {qpr_attendance}, Percentage change: {qpr_pct_change:.2f}%")
print(f"Norwich City attendance: {norwich_attendance}, Percentage change: {norwich_pct_change:.2f}%")
print(f"Swansea City attendance: {swansea_attendance}, Percentage change: {swansea_pct_change:.2f}%")
# Out:
# QPR attendance: [15616, 17295], Percentage change: 10.75%
# Norwich City attendance: [25399, 26606], Percentage change: 4.75%
# Swansea City attendance: [15507, 19946], Percentage change: 28.63%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2011/12'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2012/13'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0        Reading
# 1    Southampton
# 2       West Ham
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2011/12', '2012/13']) & 
                     data['Squad'].isin(['Reading', 'Southampton', 'West Ham'])]

# Extract the attendance data for each team and season
reading_attendance = relevant_data[(relevant_data['Squad'] == 'Reading')]['Attendance'].tolist()
southampton_attendance = relevant_data[(relevant_data['Squad'] == 'Southampton')]['Attendance'].tolist()
west_ham_attendance = relevant_data[(relevant_data['Squad'] == 'West Ham')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
reading_percentage_change = ((reading_attendance[1] - reading_attendance[0]) / reading_attendance[0]) * 100
southampton_percentage_change = ((southampton_attendance[1] - southampton_attendance[0]) / southampton_attendance[0]) * 100
west_ham_percentage_change = ((west_ham_attendance[1] - west_ham_attendance[0]) / west_ham_attendance[0]) * 100

# Print the attendance data and percentage change for each team
print(f"Reading attendance: {reading_attendance}, Percentage change: {reading_percentage_change:.2f}%")
print(f"Southampton attendance: {southampton_attendance}, Percentage change: {southampton_percentage_change:.2f}%")
print(f"West Ham attendance: {west_ham_attendance}, Percentage change: {west_ham_percentage_change:.2f}%")
# Out:
# Reading attendance: [19219, 23862], Percentage change: 24.16%
# Southampton attendance: [26420, 30855], Percentage change: 16.79%
# West Ham attendance: [30931, 34717], Percentage change: 12.24%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2012/13'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2013/14'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0      Cardiff City
# 1         Hull City
# 2    Crystal Palace
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2012/13', '2013/14']) & 
                     data['Squad'].isin(['Cardiff City', 'Hull City', 'Crystal Palace'])]

# Extract the attendance data for each team and season
cardiff_attendance = relevant_data[(relevant_data['Squad'] == 'Cardiff City')]['Attendance'].tolist()
hull_attendance = relevant_data[(relevant_data['Squad'] == 'Hull City')]['Attendance'].tolist()
palace_attendance = relevant_data[(relevant_data['Squad'] == 'Crystal Palace')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
cardiff_change = ((cardiff_attendance[1] - cardiff_attendance[0]) / cardiff_attendance[0]) * 100
hull_change = ((hull_attendance[1] - hull_attendance[0]) / hull_attendance[0]) * 100
palace_change = ((palace_attendance[1] - palace_attendance[0]) / palace_attendance[0]) * 100

# Print the percentage change in attendance for each team
print(f"Cardiff City attendance change: {cardiff_change:.2f}%")
print(f"Hull City attendance change: {hull_change:.2f}%")
print(f"Crystal Palace attendance change: {palace_change:.2f}%")
# Out:
# Cardiff City attendance change: 19.27%
# Hull City attendance change: 38.85%
# Crystal Palace attendance change: 41.06%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2013/14'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2014/15'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Leicester City
# 1           Burnley
# 2               QPR
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2013/14', '2014/15']) & 
                     data['Squad'].isin(['Leicester City', 'Burnley', 'QPR'])]

# Extract the attendance data for each team and season
leicester_attendance = relevant_data[(relevant_data['Squad'] == 'Leicester City')]['Attendance'].tolist()
burnley_attendance = relevant_data[(relevant_data['Squad'] == 'Burnley')]['Attendance'].tolist()
qpr_attendance = relevant_data[(relevant_data['Squad'] == 'QPR')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
leicester_percent_change = ((leicester_attendance[1] - leicester_attendance[0]) / leicester_attendance[0]) * 100
burnley_percent_change = ((burnley_attendance[1] - burnley_attendance[0]) / burnley_attendance[0]) * 100
qpr_percent_change = ((qpr_attendance[1] - qpr_attendance[0]) / qpr_attendance[0]) * 100

# Print the percentage change in attendance for each team
print(f"Leicester City attendance: {leicester_attendance}, % change: {leicester_percent_change:.2f}%")
print(f"Burnley attendance: {burnley_attendance}, % change: {burnley_percent_change:.2f}%")
print(f"QPR attendance: {qpr_attendance}, % change: {qpr_percent_change:.2f}%")
# Out:
# Leicester City attendance: [24990, 31693], % change: 26.82%
# Burnley attendance: [13719, 19131], % change: 39.45%
# QPR attendance: [16656, 17809], % change: 6.92%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2014/15'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2015/16'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0     Bournemouth
# 1         Watford
# 2    Norwich City
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2014/15', '2015/16']) & 
                     data['Squad'].isin(['Bournemouth', 'Watford', 'Norwich City'])]

# Extract the attendance data for each team and season
bournemouth_attendance = relevant_data[(relevant_data['Squad'] == 'Bournemouth')]['Attendance'].tolist()
watford_attendance = relevant_data[(relevant_data['Squad'] == 'Watford')]['Attendance'].tolist()
norwich_attendance = relevant_data[(relevant_data['Squad'] == 'Norwich City')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
bournemouth_pct_change = (bournemouth_attendance[1] - bournemouth_attendance[0]) / bournemouth_attendance[0] * 100
watford_pct_change = (watford_attendance[1] - watford_attendance[0]) / watford_attendance[0] * 100
norwich_pct_change = (norwich_attendance[1] - norwich_attendance[0]) / norwich_attendance[0] * 100

# Print the percentage change in attendance for each team
print(f"Bournemouth attendance change: {bournemouth_pct_change:.2f}%")
print(f"Watford attendance change: {watford_pct_change:.2f}%")
print(f"Norwich City attendance change: {norwich_pct_change:.2f}%")
# Out:
# Bournemouth attendance change: 9.00%
# Watford attendance change: 23.58%
# Norwich City attendance change: 3.07%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2015/16'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2016/17'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0          Burnley
# 1    Middlesbrough
# 2        Hull City
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2015/16', '2016/17']) & 
                     data['Squad'].isin(['Burnley', 'Middlesbrough', 'Hull City'])]

# Extract the attendance data for each team and season
burnley_attendance = relevant_data[(relevant_data['Squad'] == 'Burnley')]['Attendance'].tolist()
middlesbrough_attendance = relevant_data[(relevant_data['Squad'] == 'Middlesbrough')]['Attendance'].tolist()
hull_city_attendance = relevant_data[(relevant_data['Squad'] == 'Hull City')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
burnley_change = (burnley_attendance[1] - burnley_attendance[0]) / burnley_attendance[0] * 100
middlesbrough_change = (middlesbrough_attendance[1] - middlesbrough_attendance[0]) / middlesbrough_attendance[0] * 100
hull_city_change = (hull_city_attendance[1] - hull_city_attendance[0]) / hull_city_attendance[0] * 100

# Print the percentage change in attendance for each team
print(f"Burnley attendance change: {burnley_change:.2f}%")
print(f"Middlesbrough attendance change: {middlesbrough_change:.2f}%")
print(f"Hull City attendance change: {hull_city_change:.2f}%")
# Out:
# Burnley attendance change: 23.04%
# Middlesbrough attendance change: 23.64%
# Hull City attendance change: 20.71%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2016/17'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2017/18'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'CS'].merge(season_1011[season_1011['League'] == 'PL'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Newcastle Utd
# 1         Brighton
# 2     Huddersfield
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2016/17', '2017/18']) & 
                     data['Squad'].isin(['Newcastle Utd', 'Brighton', 'Huddersfield'])]

# Extract the attendance data for each team and season
newcastle_attendance = relevant_data[(relevant_data['Squad'] == 'Newcastle Utd')]['Attendance'].tolist()
brighton_attendance = relevant_data[(relevant_data['Squad'] == 'Brighton')]['Attendance'].tolist()
huddersfield_attendance = relevant_data[(relevant_data['Squad'] == 'Huddersfield')]['Attendance'].tolist()

# Calculate the percentage change in attendance between the two seasons for each team
newcastle_percentage_change = ((newcastle_attendance[1] - newcastle_attendance[0]) / newcastle_attendance[0]) * 100
brighton_percentage_change = ((brighton_attendance[1] - brighton_attendance[0]) / brighton_attendance[0]) * 100
huddersfield_percentage_change = ((huddersfield_attendance[1] - huddersfield_attendance[0]) / huddersfield_attendance[0]) * 100

# Print the percentage change in attendance for each team
print(f"Newcastle Utd attendance change: {newcastle_percentage_change:.2f}%")
print(f"Brighton attendance change: {brighton_percentage_change:.2f}%")
print(f"Huddersfield attendance change: {huddersfield_percentage_change:.2f}%")
# Out:
# Newcastle Utd attendance change: 1.73%
# Brighton attendance change: 8.60%
# Huddersfield attendance change: 18.17%

# %%
import matplotlib.pyplot as plt

# Data for each team and their attendance change
teams = ['Newcastle Utd', 'West Brom', 'Blackpool', 'QPR', 'Norwich City', 'Swansea City', 'Reading', 'Southampton', 'West Ham', 'Cardiff City', 'Hull City', 'Crystal Palace', 'Leicester City', 'Burnley', 'Bournemouth', 'Watford', 'Brighton', 'Huddersfield']
attendance_changes = [9.98, 11.19, 83.20, 10.75, 4.75, 28.63, 24.16, 16.79, 12.24, 19.27, 38.85, 41.06, 26.82, 39.45, 9.00, 23.58, 8.60, 18.17]

# Calculate the average attendance change
average_attendance_change = sum(attendance_changes) / len(attendance_changes)

# Create a bar chart of the attendance change for each team
fig, ax = plt.subplots()
ax.bar(teams, attendance_changes)
ax.set_ylabel('Attendance Change (%)')
ax.set_title('Attendance Change for Teams')
plt.xticks(rotation=90)

# Add a horizontal line showing the average attendance change
ax.axhline(average_attendance_change, color='r', linestyle='--', label=f'Average: {average_attendance_change:.2f}%')
ax.legend()

plt.show()

## blackpool reaching prem first time
## norwich yoyo
## newcastle historic

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2009/10'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2010/11'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0       Burnley
# 1     Hull City
# 2    Portsmouth
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2009/10', '2010/11']) & 
                     data['Squad'].isin(['Burnley', 'Hull City', 'Portsmouth'])]

# Extract the attendance data for each team and season
burnley_attendance = relevant_data[(relevant_data['Squad'] == 'Burnley')]['Attendance'].tolist()
hull_city_attendance = relevant_data[(relevant_data['Squad'] == 'Hull City')]['Attendance'].tolist()
portsmouth_attendance = relevant_data[(relevant_data['Squad'] == 'Portsmouth')]['Attendance'].tolist()

# Calculate the percent change in attendance
burnley_pct_change = (burnley_attendance[1] - burnley_attendance[0]) / burnley_attendance[0] * 100
hull_city_pct_change = (hull_city_attendance[1] - hull_city_attendance[0]) / hull_city_attendance[0] * 100
portsmouth_pct_change = (portsmouth_attendance[1] - portsmouth_attendance[0]) / portsmouth_attendance[0] * 100

# Print the percent change in attendance for each team
print(f"Burnley percent change in attendance: {burnley_pct_change:.2f}%")
print(f"Hull City percent change in attendance: {hull_city_pct_change:.2f}%")
print(f"Portsmouth percent change in attendance: {portsmouth_pct_change:.2f}%")
# Out:
# Burnley percent change in attendance: -27.71%
# Hull City percent change in attendance: -13.21%
# Portsmouth percent change in attendance: -13.93%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2010/11'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2011/12'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Birmingham City
# 1          Blackpool
# 2           West Ham
# Name: Squad, dtype: object

# %%
# Define the teams and seasons of interest
teams = ['Birmingham City', 'Blackpool', 'West Ham']
seasons = ['2010/11', '2011/12']

# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(seasons) & data['Squad'].isin(teams)]

# Calculate the attendance percent change for each team and season
for team in teams:
    team_data = relevant_data[relevant_data['Squad'] == team]
    attendance = team_data['Attendance'].tolist()
    percent_change = (attendance[1] - attendance[0]) / attendance[0] * 100
    print(f"{team}: {percent_change:.2f}%")
# Out:
# Birmingham City: -25.84%
# Blackpool: -19.09%
# West Ham: -7.65%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2011/12'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2012/13'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0       Bolton
# 1    Blackburn
# 2       Wolves
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2011/12', '2012/13']) & 
                     data['Squad'].isin(['Bolton', 'Blackburn', 'Wolves'])]

# Extract the attendance data for each team and season
bolton_attendance = relevant_data[(relevant_data['Squad'] == 'Bolton')]['Attendance'].tolist()
blackburn_attendance = relevant_data[(relevant_data['Squad'] == 'Blackburn')]['Attendance'].tolist()
wolves_attendance = relevant_data[(relevant_data['Squad'] == 'Wolves')]['Attendance'].tolist()

# Calculate the percent change in attendance for each team
bolton_percent_change = ((bolton_attendance[1] - bolton_attendance[0]) / bolton_attendance[0]) * 100
blackburn_percent_change = ((blackburn_attendance[1] - blackburn_attendance[0]) / blackburn_attendance[0]) * 100
wolves_percent_change = ((wolves_attendance[1] - wolves_attendance[0]) / wolves_attendance[0]) * 100

# Print the percent change in attendance for each team
print(f"Bolton percent change: {bolton_percent_change:.2f}%")
print(f"Blackburn percent change: {blackburn_percent_change:.2f}%")
print(f"Wolves percent change: {wolves_percent_change:.2f}%")
# Out:
# Bolton percent change: -23.81%
# Blackburn percent change: -33.50%
# Wolves percent change: -15.20%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2012/13'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2013/14'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Wigan Athletic
# 1           Reading
# 2               QPR
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2012/13', '2013/14']) & 
                     data['Squad'].isin(['Wigan Athletic', 'Reading', 'QPR'])]

# Extract the attendance data for each team and season
wigan_attendance = relevant_data[(relevant_data['Squad'] == 'Wigan Athletic')]['Attendance'].tolist()
reading_attendance = relevant_data[(relevant_data['Squad'] == 'Reading')]['Attendance'].tolist()
qpr_attendance = relevant_data[(relevant_data['Squad'] == 'QPR')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
wigan_percent_change = (wigan_attendance[1] - wigan_attendance[0]) / wigan_attendance[0] * 100
reading_percent_change = (reading_attendance[1] - reading_attendance[0]) / reading_attendance[0] * 100
qpr_percent_change = (qpr_attendance[1] - qpr_attendance[0]) / qpr_attendance[0] * 100

# Print the attendance data and percentage change for each team
print(f"Wigan Athletic attendance: {wigan_attendance}, Percent change: {wigan_percent_change:.2f}%")
print(f"Reading attendance: {reading_attendance}, Percent change: {reading_percent_change:.2f}%")
print(f"QPR attendance: {qpr_attendance}, Percent change: {qpr_percent_change:.2f}%")
# Out:
# Wigan Athletic attendance: [19359, 15177], Percent change: -21.60%
# Reading attendance: [23862, 19171], Percent change: -19.66%
# QPR attendance: [17779, 16656], Percent change: -6.32%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2013/14'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2014/15'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Norwich City
# 1          Fulham
# 2    Cardiff City
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2013/14', '2014/15']) & 
                     data['Squad'].isin(['Norwich City', 'Fulham', 'Cardiff City'])]

# Extract the attendance data for each team and season
norwich_attendance = relevant_data[(relevant_data['Squad'] == 'Norwich City')]['Attendance'].tolist()
fulham_attendance = relevant_data[(relevant_data['Squad'] == 'Fulham')]['Attendance'].tolist()
cardiff_attendance = relevant_data[(relevant_data['Squad'] == 'Cardiff City')]['Attendance'].tolist()

# Calculate the percent change for each team's attendance
norwich_percent_change = (norwich_attendance[1] - norwich_attendance[0]) / norwich_attendance[0] * 100
fulham_percent_change = (fulham_attendance[1] - fulham_attendance[0]) / fulham_attendance[0] * 100
cardiff_percent_change = (cardiff_attendance[1] - cardiff_attendance[0]) / cardiff_attendance[0] * 100

# Print the attendance data and percent change for each team
print(f"Norwich City attendance: {norwich_attendance}, Percent change: {norwich_percent_change:.2f}%")
print(f"Fulham attendance: {fulham_attendance}, Percent change: {fulham_percent_change:.2f}%")
print(f"Cardiff City attendance: {cardiff_attendance}, Percent change: {cardiff_percent_change:.2f}%")
# Out:
# Norwich City attendance: [26805, 26169], Percent change: -2.37%
# Fulham attendance: [24977, 18276], Percent change: -26.83%
# Cardiff City attendance: [27430, 21124], Percent change: -22.99%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2014/15'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2015/16'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Hull City
# 1      Burnley
# 2          QPR
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2014/15', '2015/16']) & 
                     data['Squad'].isin(['Hull City', 'Burnley', 'QPR'])]

# Extract the attendance data for each team and season
hull_attendance = relevant_data[(relevant_data['Squad'] == 'Hull City')]['Attendance'].tolist()
burnley_attendance = relevant_data[(relevant_data['Squad'] == 'Burnley')]['Attendance'].tolist()
QPR_attendance = relevant_data[(relevant_data['Squad'] == 'QPR')]['Attendance'].tolist()

# Calculate the percent change in attendance for each team
hull_percent_change = ((hull_attendance[1] - hull_attendance[0]) / hull_attendance[0]) * 100
burnley_percent_change = ((burnley_attendance[1] - burnley_attendance[0]) / burnley_attendance[0]) * 100
QPR_percent_change = ((QPR_attendance[1] - QPR_attendance[0]) / QPR_attendance[0]) * 100

# Print the percent change in attendance for each team
print(f"Hull City attendance change: {hull_percent_change:.2f}%")
print(f"Burnley attendance change: {burnley_percent_change:.2f}%")
print(f"QPR attendance change: {QPR_percent_change:.2f}%")
# Out:
# Hull City attendance change: -26.99%
# Burnley attendance change: -12.66%
# QPR attendance change: -10.19%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2015/16'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2016/17'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']

print(promoted_teams)
# Out:
# 0    Newcastle Utd
# 1     Norwich City
# 2      Aston Villa
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2015/16', '2016/17']) & 
                     data['Squad'].isin(['Newcastle Utd', 'Norwich City', 'Aston Villa'])]

# Calculate the percentage change in attendance for each team
newcastle_attendance = relevant_data[(relevant_data['Squad'] == 'Newcastle Utd')]['Attendance'].tolist()
newcastle_pct_change = ((newcastle_attendance[1] - newcastle_attendance[0]) / newcastle_attendance[0]) * 100

norwich_attendance = relevant_data[(relevant_data['Squad'] == 'Norwich City')]['Attendance'].tolist()
norwich_pct_change = ((norwich_attendance[1] - norwich_attendance[0]) / norwich_attendance[0]) * 100

villa_attendance = relevant_data[(relevant_data['Squad'] == 'Aston Villa')]['Attendance'].tolist()
villa_pct_change = ((villa_attendance[1] - villa_attendance[0]) / villa_attendance[0]) * 100

# Print the percentage change in attendance for each team
print(f"Newcastle Utd attendance change: {newcastle_pct_change:.2f}%")
print(f"Norwich City attendance change: {norwich_pct_change:.2f}%")
print(f"Aston Villa attendance change: {villa_pct_change:.2f}%")
# Out:
# Newcastle Utd attendance change: 2.72%
# Norwich City attendance change: -2.29%
# Aston Villa attendance change: -4.70%

# %%
# Filter the data to show only PL and CS teams in 2009/10 and 2010/11 seasons
season_0910 = data[data['Year'] == '2016/17'][['Squad', 'League']]
season_1011 = data[data['Year'] == '2017/18'][['Squad', 'League']]

# Find the teams that were in the CS in 2009/10 and in the PL in 2010/11
promoted_teams = season_0910[season_0910['League'] == 'PL'].merge(season_1011[season_1011['League'] == 'CS'], on='Squad')['Squad']
print(promoted_teams)
# Out:
# 0        Hull City
# 1    Middlesbrough
# 2       Sunderland
# Name: Squad, dtype: object

# %%
# Filter the data to include only the relevant seasons and teams
relevant_data = data[data['Year'].isin(['2016/17', '2017/18']) & 
                     data['Squad'].isin(['Hull City', 'Middlesbrough', 'Sunderland'])]

# Extract the attendance data for each team and season
hull_attendance = relevant_data[(relevant_data['Squad'] == 'Hull City')]['Attendance'].tolist()
middlesbrough_attendance = relevant_data[(relevant_data['Squad'] == 'Middlesbrough')]['Attendance'].tolist()
sunderland_attendance = relevant_data[(relevant_data['Squad'] == 'Sunderland')]['Attendance'].tolist()

# Calculate the percentage change in attendance for each team
hull_change = ((hull_attendance[1] - hull_attendance[0]) / hull_attendance[0]) * 100
middlesbrough_change = ((middlesbrough_attendance[1] - middlesbrough_attendance[0]) / middlesbrough_attendance[0]) * 100
sunderland_change = ((sunderland_attendance[1] - sunderland_attendance[0]) / sunderland_attendance[0]) * 100

# Print the percentage change in attendance for each team
print(f"Hull City attendance change: {hull_change:.2f}%")
print(f"Middlesbrough attendance change: {middlesbrough_change:.2f}%")
print(f"Sunderland attendance change: {sunderland_change:.2f}%")
# Out:
# Hull City attendance change: -24.75%
# Middlesbrough attendance change: -16.11%
# Sunderland attendance change: -33.07%

# %%
import matplotlib.pyplot as plt

# Define the data
teams = ['Burnley', 'Hull City', 'Portsmouth', 'Birmingham City', 'Blackpool', 'West Ham', 'Bolton', 'Blackburn', 'Wolves', 'Wigan Athletic', 'Reading', 'QPR', 'Norwich City', 'Fulham', 'Cardiff City', 'Newcastle Utd', 'Aston Villa', 'Middlesbrough', 'Sunderland']
percent_changes = [-27.71, -13.21, -13.93, -25.84, -19.09, -7.65, -23.81, -33.50, -15.20, -21.60, -19.66, -6.32, -2.37, -26.83, -22.99, 2.72, -4.70, -16.11, -33.07]
average_percent_change = sum(percent_changes) / len(percent_changes)

# Create the bar chart
fig, ax = plt.subplots()
ax.bar(teams, percent_changes)
ax.axhline(y=average_percent_change, color='r', linestyle='--', label='Average')
ax.set_xticklabels(teams, rotation=90)
ax.set_ylabel('Percent Change')
ax.set_title('Average Percent Change in Attendance for Teams Relegated from the PL to the CS')

ax.legend()
plt.show()
# Out:
# <ipython-input-151-c6006c4cc310>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(teams, rotation=90)

# %%
data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League
# 0         41423    2009/10     PL
# 1         74864    2009/10     PL
# 2         59927    2009/10     PL
# ...

# %%
clubs = data['Squad'].unique()
print(clubs)
# Out:
# ['Chelsea' 'Manchester Utd' 'Arsenal' 'Tottenham' 'Manchester City'
#  'Aston Villa' 'Liverpool' 'Everton' 'Birmingham City' 'Blackburn'
#  'Stoke City' 'Fulham' 'Sunderland' 'Bolton' 'Wolves' 'Wigan Athletic'
#  'West Ham' 'Burnley' 'Hull City' 'Portsmouth' 'Newcastle Utd' 'West Brom'
#  "Nott'ham Forest" 'Cardiff City' 'Leicester City' 'Blackpool'
#  'Swansea City' 'Sheffield Utd' 'Reading' 'Bristol City' 'Middlesbrough'
#  'Doncaster' 'QPR' 'Derby County' 'Ipswich Town' 'Watford' 'Preston'
#  'Barnsley' 'Coventry City' 'Scunthorpe Utd' 'Crystal Palace'
#  'Sheffield Weds' 'Plymouth Argyle' "P'borough Utd" 'Norwich City'
#  'Leeds United' 'Millwall' 'Southampton' 'Brighton' 'Charlton Ath'
#  'Huddersfield' 'Bournemouth' 'Yeovil Town' 'Brentford' 'Rotherham Utd'
#  'MK Dons' 'Burton Albion']

# %%
# Read in the stadium capacity data from CSV
stadium_data = pd.read_csv('staidum capacity.csv')

# Merge the stadium capacity data with the original data frame
merged_data = pd.merge(data, stadium_data, on='Squad', how='left')

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League                       Stadium Capacity
# 0         41423    2009/10     PL               Stamford Bridge   41,837
# ...

# %%
# filter the dataframe to only include seasons from 2009/10 to 2015/16
df_filtered = merged_data[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2015/16')]

# update the capacity of West Ham's stadium for those seasons
df_filtered.loc[df_filtered['Squad'] == 'West Ham', 'Capacity'] = '35,016'

# update the capacity of Leeds United's stadium for those seasons
df_filtered.loc[df_filtered['Squad'] == 'Leeds United', 'Capacity'] = '37,890'

# update the capacity of Charlton Athletic's stadium for those seasons
df_filtered.loc[df_filtered['Squad'] == 'Charlton Athletic', 'Capacity'] = '27,111'

# save the filtered dataset to a new csv file
df_filtered.to_csv('modified_dataset.csv', index=False)

# %%
df_filtered
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 303  20           Fulham  46  12  15  19   66  79 -13   51    1.11
# 304  21    Rotherham Utd  46  13  10  23   53  71 -18   49    1.07
# 305  22     Charlton Ath  46   9  13  24   40  80 -40   40    0.87
# 306  23          MK Dons  46   9  12  25   39  69 -30   39    0.85
# 307  24           Bolton  46   5  15  26   41  81 -40   30    0.65
#
#      Attendance     Year League                       Stadium Capacity
# 0         41423  2009/10     PL               Stamford Bridge   41,837
# ...

# %%
# update the capacity of West Ham's stadium for the specified seasons
merged_data.loc[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2015/16') & (merged_data['Squad'] == 'West Ham'), 'Capacity'] = '35,016'

# update the capacity of Leeds United's stadium for the specified seasons
merged_data.loc[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2015/16') & (merged_data['Squad'] == 'Leeds United'), 'Capacity'] = '37,890'

# update the capacity of Charlton Athletic's stadium for the specified seasons
merged_data.loc[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2015/16') & (merged_data['Squad'] == 'Charlton Athletic'), 'Capacity'] = '27,111'

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League                       Stadium Capacity
# 0         41423    2009/10     PL               Stamford Bridge   41,837
# ...

# %%
# update the capacity of Tottenham Hotspur's stadium for the specified seasons
merged_data.loc[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2016/17') & (merged_data['Squad'] == 'Tottenham'), 'Capacity'] = '36,284'

# %%
# update the capacity of Manchester City's stadium for the specified seasons
merged_data.loc[(merged_data['Year'] >= '2009/10') & (merged_data['Year'] <= '2014/15') & (merged_data['Squad'] == 'Manchester City'), 'Capacity'] = '47,805'

# %%
merged_data.loc[(merged_data['Squad'] == 'Tottenham') & (merged_data['Year'] == '2017/18'), 'Capacity'] = 90000

# %%
merged_data['Capacity'].isna().sum()
# Out:
# 7

# %%
# update the capacity of Leeds United's stadium for those seasons
merged_data.loc[merged_data['Squad'] == 'Leeds United', 'Capacity'] = '37,890'

# update the capacity of Charlton Athletic's stadium for those seasons
merged_data.loc[merged_data['Squad'] == 'Charlton Ath', 'Capacity'] = '27,111'

# %%
merged_data[merged_data['Capacity'].isna()]
# Out:
# Empty DataFrame
# Columns: [Rk, Squad, MP, W, D, L, GF, GA, GD, Pts, Pts/MP, Attendance, Year, League, Stadium, Capacity]
# Index: []

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League                       Stadium Capacity
# 0         41423    2009/10     PL               Stamford Bridge   41,837
# ...

# %%
merged_data = merged_data.drop('Stadium', axis=1)

# %%
# Find rows with missing values in the 'Capacity' column
missing_values = merged_data['Capacity'].isna()
print(missing_values)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 435    False
# 436    False
# 437    False
# 438    False
# 439    False
# Name: Capacity, Length: 440, dtype: bool

# %%
merged_data['Capacity'].isna().sum()
# Out:
# 0

# %%
merged_data['Capacity'] = merged_data['Capacity'].str.replace(',', '')

# %%
merged_data['Capacity'].isna().sum()
# Out:
# 1

# %%
merged_data['Capacity'] = merged_data['Capacity'].fillna(90000)

# %%
print(merged_data['Attendance'].dtype)
print(merged_data['Capacity'].dtype)
# Out:
# int64
# object

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League Capacity
# 0         41423    2009/10     PL    41837
# 1         74864    2009/10     PL    74140
# ...

# %%
merged_data['Capacity'] = merged_data['Capacity'].astype(int)

# %%
merged_data['% Capacity Filled'] = (merged_data['Attendance'] / merged_data['Capacity']) * 100

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League  Capacity  % Capacity Filled
# 0         41423    2009/10     PL     41837          99.010445
# ...

# %%
merged_data.loc[merged_data['Squad'] == 'Manchester Utd', 'Capacity'] = 75731

# %%
merged_data.loc[merged_data['Squad'] == 'Fulham', 'Capacity'] = 25700

# %%
merged_data['% Capacity Filled'] = (merged_data['Attendance'] / merged_data['Capacity']) * 100

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League  Capacity  % Capacity Filled
# 0         41423    2009/10     PL     41837          99.010445
# ...

# %%
merged_data.loc[(merged_data['Squad'] == 'Liverpool') & (merged_data['Year'].isin(['2009/10', '2010/11', '2011/12', '2012/13', '2013/14', '2014/15', '2015/16'])), 'Capacity'] = 45500

# %%
merged_data['% Capacity Filled'] = (merged_data['Attendance'] / merged_data['Capacity']) * 100

# %%
merged_data
# Out:
#      Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1          Chelsea  38  27   5   6  103  32  71   86    2.26
# 1     2   Manchester Utd  38  27   4   7   86  28  58   85    2.24
# 2     3          Arsenal  38  23   6   9   83  41  42   75    1.97
# 3     4        Tottenham  38  21   7  10   67  41  26   70    1.84
# 4     5  Manchester City  38  18  13   7   73  45  28   67    1.76
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 435  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 436  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 437  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 438  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 439  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League  Capacity  % Capacity Filled
# 0         41423    2009/10     PL     41837          99.010445
# ...

# %%
# Calculate the total attendance for each club across all seasons
total_attendance = merged_data.groupby('Squad')['Attendance'].sum()

# Calculate the total capacity for each club across all seasons
total_capacity = merged_data.groupby('Squad')['Capacity'].sum()

# Divide the total attendance by the total capacity for each club to get the average capacity filled
average_capacity_filled = total_attendance / total_capacity

# Sort the clubs in descending order of average capacity filled
average_capacity_filled = average_capacity_filled.sort_values(ascending=False)

# Print the results
print(average_capacity_filled)
# Out:
# Squad
# Arsenal            0.994290
# Manchester Utd     0.992304
# Chelsea            0.988501
# Liverpool          0.975541
# Manchester City    0.974740
# Norwich City       0.965660
# West Ham           0.962026
# Newcastle Utd      0.948860
# Everton            0.945088
# Bournemouth        0.938020
# Southampton        0.926196
# West Brom          0.915344
# Swansea City       0.915156
# Tottenham          0.914466
# Stoke City         0.899442
# Fulham             0.871825
# Brighton           0.868293
# Leicester City     0.856363
# QPR                0.850957
# Crystal Palace     0.831519
# Rotherham Utd      0.830380
# Aston Villa        0.815344
# Sunderland         0.808002
# Derby County       0.807798
# Wolves             0.793512
# Burnley            0.792472
# Portsmouth         0.791659
# Hull City          0.766551
# Nott'ham Forest    0.759116
# Sheffield Utd      0.755176
# Watford            0.753347
# Reading            0.748318
# Blackpool          0.734956
# ...

# %%
# Create the data series
data1 = pd.Series({'Arsenal': 0.994290, 'Manchester Utd': 0.992304, 'Chelsea': 0.988501, 'Liverpool': 0.975541, 
                  'Manchester City': 0.974740, 'Norwich City': 0.965660, 'West Ham': 0.962026, 'Newcastle Utd': 0.948860, 
                  'Everton': 0.945088, 'Bournemouth': 0.938020, 'Southampton': 0.926196, 'West Brom': 0.915344, 
                  'Swansea City': 0.915156, 'Tottenham': 0.914466, 'Stoke City': 0.899442, 'Fulham': 0.871825, 
                  'Brighton': 0.868293, 'Leicester City': 0.856363, 'QPR': 0.850957, 'Crystal Palace': 0.831519, 
                  'Rotherham Utd': 0.830380, 'Aston Villa': 0.815344, 'Sunderland': 0.808002, 'Derby County': 0.807798, 
                  'Wolves': 0.793512, 'Burnley': 0.792472, 'Portsmouth': 0.791659, 'Hull City': 0.766551, 
                  'Nott\'ham Forest': 0.759116, 'Sheffield Utd': 0.755176, 'Watford': 0.753347, 'Reading': 0.748318, 
                  'Blackpool': 0.734956, 'Huddersfield': 0.717324, 'Burton Albion': 0.714193, 'Leeds United': 0.694983, 
                  'Yeovil Town': 0.691688, 'Sheffield Weds': 0.683863, 'Birmingham City': 0.672270, 'Cardiff City': 0.666836, 
                  'Scunthorpe Utd': 0.660871, 'Doncaster': 0.650515, 'Bolton': 0.631592, 'Wigan Athletic': 0.617864, 
                  'Charlton Ath': 0.617581, 'Bristol City': 0.615653, 'Brentford': 0.606261, 'Ipswich Town': 0.603642, 
                  'Middlesbrough': 0.601949, 'Millwall': 0.591759, 'Plymouth Argyle': 0.576184, 'P\'borough Utd': 0.571133, 
                  'Blackburn': 0.564000, 'Preston': 0.557447, 'Barnsley': 0.518076, 'Coventry City': 0.498165, 
                  'MK Dons': 0.431410})


# Create the bar chart
fig, ax = plt.subplots(figsize=(20,10))
bar_chart = sns.barplot(x=average_capacity_filled.index, y=average_capacity_filled.values, color='blue')

# Set the title and labels
ax.set_title('Average Capacity Filled for English Football Clubs since 2009', fontsize=18)
ax.set_xlabel('Club', fontsize=14)
ax.set_ylabel('Average Capacity Filled', fontsize=14)

# Set the x and y axis tick label size
ax.tick_params(axis='both', which='major', labelsize=12)

# Rotate x-axis labels for better readability
bar_chart.set_xticklabels(bar_chart.get_xticklabels(), rotation=90, ha='center')
# Rotate the x-axis labels by 45 degrees
plt.xticks(rotation=85)
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(merged_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
cs_teams = merged_data[merged_data['League']=='CS']
avg_capacity_filled = cs_teams['% Capacity Filled'].mean()
print("Average capacity filled for CS teams:", avg_capacity_filled)
# Out:
# Average capacity filled for CS teams: 67.31057110151966

# %%
pl_avg_capacity_filled = merged_data[merged_data['League'] == 'PL']['% Capacity Filled'].mean()
print("Average capacity filled for PL teams:", pl_avg_capacity_filled)
# Out:
# Average capacity filled for PL teams: 93.71315434563341

# %%
# Data
cs_capacity = 67.31057110151966
pl_capacity = 93.71315434563341

# Create a bar chart
plt.bar(["CS Teams", "PL Teams"], [cs_capacity, pl_capacity])

# Add a title and axis labels
plt.title("Average Stadium Capacity Filled")
plt.xlabel("League")
plt.ylabel("Capacity Filled (%)")

# Show the plot
plt.show()

# %%
relegated_teams= merged_data[(merged_data['Rk'].isin([18, 19, 20])) & (merged_data['League'] == 'PL')][['Squad', 'Rk', 'MP', 'W', 'D','L','GA','GD','Pts','Pts/MP']]

# %%
relegated_teams
# Out:
#                Squad  Rk  MP   W   D   L  GA  GD  Pts  Pts/MP
# 17           Burnley  18  38   8   6  24  82 -40   30    0.79
# 18         Hull City  19  38   6  12  20  75 -41   30    0.79
# 19        Portsmouth  20  38   7   7  24  66 -32   19    0.50
# 61   Birmingham City  18  38   8  15  15  58 -21   39    1.03
# 62         Blackpool  19  38  10   9  19  78 -23   39    1.03
# 63          West Ham  20  38   7  12  19  70 -27   33    0.87
# 105           Bolton  18  38  10   6  22  77 -31   36    0.95
# 106        Blackburn  19  38   8   7  23  78 -30   31    0.82
# 107           Wolves  20  38   5  10  23  82 -42   25    0.66
# 149   Wigan Athletic  18  38   9   9  20  73 -26   36    0.95
# 150          Reading  19  38   6  10  22  73 -30   28    0.74
# 151              QPR  20  38   4  13  21  60 -30   25    0.66
# 193     Norwich City  18  38   8   9  21  62 -34   33    0.87
# 194           Fulham  19  38   9   5  24  85 -45   32    0.84
# ...

# %%
# Calculate the average values of each column in the DataFrame
avg_values = relegated_teams.mean()

# Print the resulting Series
print(avg_values)
# Out:
# Rk        19.000000
# MP        38.000000
# W          7.233333
# D          8.966667
# L         21.800000
# GA        69.533333
# GD       -33.233333
# Pts       30.366667
# Pts/MP     0.799667
# dtype: float64
# <ipython-input-193-0da2b7c09b1c>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_values = relegated_teams.mean()

# %%
# Multiply the values in the "W", "D", "L", "GA", "GD", and "Pts" columns by 27/38
relegated_teams_27 = relegated_teams.copy()
relegated_teams_27["MP"] = 27
relegated_teams_27[["W", "D", "L", "GA", "GD", "Pts"]] = relegated_teams_27[["W", "D", "L", "GA", "GD", "Pts"]] * 27/38

# Round the resulting values to the nearest whole number
relegated_teams_27 = relegated_teams_27.round({"W": 0, "D": 0, "L": 0, "GA": 0, "GD": 0, "Pts": 0, "Pts/MP": 2})

# Print the resulting DataFrame
print(relegated_teams_27)
# Out:
#                Squad  Rk  MP    W     D     L    GA    GD   Pts  Pts/MP
# 17           Burnley  18  27  6.0   4.0  17.0  58.0 -28.0  21.0    0.79
# 18         Hull City  19  27  4.0   9.0  14.0  53.0 -29.0  21.0    0.79
# 19        Portsmouth  20  27  5.0   5.0  17.0  47.0 -23.0  14.0    0.50
# 61   Birmingham City  18  27  6.0  11.0  11.0  41.0 -15.0  28.0    1.03
# 62         Blackpool  19  27  7.0   6.0  14.0  55.0 -16.0  28.0    1.03
# 63          West Ham  20  27  5.0   9.0  14.0  50.0 -19.0  23.0    0.87
# 105           Bolton  18  27  7.0   4.0  16.0  55.0 -22.0  26.0    0.95
# 106        Blackburn  19  27  6.0   5.0  16.0  55.0 -21.0  22.0    0.82
# 107           Wolves  20  27  4.0   7.0  16.0  58.0 -30.0  18.0    0.66
# 149   Wigan Athletic  18  27  6.0   6.0  14.0  52.0 -18.0  26.0    0.95
# 150          Reading  19  27  4.0   7.0  16.0  52.0 -21.0  20.0    0.74
# 151              QPR  20  27  3.0   9.0  15.0  43.0 -21.0  18.0    0.66
# ...

# %%
# Calculate the average of each column in the DataFrame
averages = relegated_teams_27.mean().round(0)

# Print the resulting Series
print(averages)
# Out:
# Rk        19.0
# MP        27.0
# W          5.0
# D          6.0
# L         16.0
# GA        49.0
# GD       -24.0
# Pts       22.0
# Pts/MP     1.0
# dtype: float64
# <ipython-input-195-a617c0daf600>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages = relegated_teams_27.mean().round(0)

# %%
relegated_teams_1= merged_data[(merged_data['Rk'].isin([18])) & (merged_data['League'] == 'PL')][['Squad', 'Rk', 'MP', 'W', 'D','L','GA','GD','Pts','Pts/MP']]

# %%
relegated_teams_1
# Out:
#                Squad  Rk  MP   W   D   L  GA  GD  Pts  Pts/MP
# 17           Burnley  18  38   8   6  24  82 -40   30    0.79
# 61   Birmingham City  18  38   8  15  15  58 -21   39    1.03
# 105           Bolton  18  38  10   6  22  77 -31   36    0.95
# 149   Wigan Athletic  18  38   9   9  20  73 -26   36    0.95
# 193     Norwich City  18  38   8   9  21  62 -34   33    0.87
# 237        Hull City  18  38   8  11  19  51 -18   35    0.92
# 281    Newcastle Utd  18  38   9  10  19  65 -21   37    0.97
# 325        Hull City  18  38   9   7  22  80 -43   34    0.89
# 369     Swansea City  18  38   8   9  21  56 -28   33    0.87
# 413     Cardiff City  18  38  10   4  24  69 -35   34    0.89

# %%
# Calculate the average values of each column in the DataFrame
avg_values = relegated_teams_1.mean()

# Print the resulting Series
print(avg_values)
# Out:
# Rk        18.000
# MP        38.000
# W          8.700
# D          8.600
# L         20.700
# GA        67.300
# GD       -29.700
# Pts       34.700
# Pts/MP     0.913
# dtype: float64
# <ipython-input-198-6a4787873ad4>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_values = relegated_teams_1.mean()

# %%
# Multiply the values in the "W", "D", "L", "GA", "GD", and "Pts" columns by 28/38
relegated_teams_27_1 = relegated_teams_1.copy()
relegated_teams_27_1["MP"] = 28
relegated_teams_27_1[["W", "D", "L", "GA", "GD", "Pts"]] = relegated_teams_27_1[["W", "D", "L", "GA", "GD", "Pts"]] * 28/38

# Round the resulting values to the nearest whole number
relegated_teams_27_1 = relegated_teams_27_1.round({"W": 0, "D": 0, "L": 0, "GA": 0, "GD": 0, "Pts": 0, "Pts/MP": 2})

# Print the resulting DataFrame
print(relegated_teams_27_1)
# Out:
#                Squad  Rk  MP    W     D     L    GA    GD   Pts  Pts/MP
# 17           Burnley  18  28  6.0   4.0  18.0  60.0 -29.0  22.0    0.79
# 61   Birmingham City  18  28  6.0  11.0  11.0  43.0 -15.0  29.0    1.03
# 105           Bolton  18  28  7.0   4.0  16.0  57.0 -23.0  27.0    0.95
# 149   Wigan Athletic  18  28  7.0   7.0  15.0  54.0 -19.0  27.0    0.95
# 193     Norwich City  18  28  6.0   7.0  15.0  46.0 -25.0  24.0    0.87
# 237        Hull City  18  28  6.0   8.0  14.0  38.0 -13.0  26.0    0.92
# 281    Newcastle Utd  18  28  7.0   7.0  14.0  48.0 -15.0  27.0    0.97
# 325        Hull City  18  28  7.0   5.0  16.0  59.0 -32.0  25.0    0.89
# 369     Swansea City  18  28  6.0   7.0  15.0  41.0 -21.0  24.0    0.87
# 413     Cardiff City  18  28  7.0   3.0  18.0  51.0 -26.0  25.0    0.89

# %%
# Calculate the average of each column in the DataFrame
averages = relegated_teams_27_1.mean()

# Print the resulting Series
print(averages)
# Out:
# Rk        18.000
# MP        28.000
# W          6.500
# D          6.300
# L         15.200
# GA        49.700
# GD       -21.800
# Pts       25.600
# Pts/MP     0.913
# dtype: float64
# <ipython-input-200-e43fdbd79c56>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   averages = relegated_teams_27_1.mean()

# %%
promoted_teams = merged_data[(merged_data['Rk'].isin([1, 2])) & (merged_data['League'] == 'CS')][['Squad', 'Rk', 'MP', 'W', 'D', 'L', 'GA', 'GD', 'Pts', 'Pts/MP']]

# %%
promoted_teams
# Out:
#               Squad  Rk  MP   W   D   L  GA  GD  Pts  Pts/MP
# 20    Newcastle Utd   1  46  30  12   4  35  55  102    2.22
# 21        West Brom   2  46  26  13   7  48  41   91    1.98
# 64              QPR   1  46  24  16   6  32  39   88    1.91
# 65     Norwich City   2  46  23  15   8  58  25   84    1.83
# 108         Reading   1  46  27   8  11  41  28   89    1.93
# 109     Southampton   2  46  26  10  10  46  39   88    1.91
# 152    Cardiff City   1  46  25  12   9  45  27   87    1.89
# 153       Hull City   2  46  24   7  15  52   9   79    1.72
# 196  Leicester City   1  46  31   9   6  43  40  102    2.22
# 197         Burnley   2  46  26  15   5  37  35   93    2.02
# 240     Bournemouth   1  46  26  12   8  45  53   90    1.96
# 241         Watford   2  46  27   8  11  50  41   89    1.93
# 284         Burnley   1  46  26  15   5  35  37   93    2.02
# 285   Middlesbrough   2  46  26  11   9  31  32   89    1.93
# ...

# %%
promoted_teams_rk2 = promoted_teams[promoted_teams['Rk'] == 2]
promoted_teams_rk2_avg = promoted_teams_rk2.mean()
promoted_teams_rk2_avg
# Out:
# <ipython-input-203-712648ea4897>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   promoted_teams_rk2_avg = promoted_teams_rk2.mean()
# Rk         2.000
# MP        46.000
# W         25.900
# D         10.800
# L          9.300
# GA        44.200
# GD        32.300
# Pts       88.500
# Pts/MP     1.923
# dtype: float64

# %%
promoted_teams_37=promoted_teams_rk2.copy()
promoted_teams_37["MP"]= 37
promoted_teams_37[["W", "D", "L", "GA", "GD", "Pts"]] = promoted_teams_37[["W", "D", "L", "GA", "GD", "Pts"]] * 37/46

# Round the resulting values to the nearest whole number
promoted_teams_37 = promoted_teams_37.round({"W": 0, "D": 0, "L": 0, "GA": 0, "GD": 0, "Pts": 0, "Pts/MP": 2})

# Print the resulting DataFrame
print(promoted_teams_37)
# Out:
#              Squad  Rk  MP     W     D     L    GA    GD   Pts  Pts/MP
# 21       West Brom   2  37  21.0  10.0   6.0  39.0  33.0  73.0    1.98
# 65    Norwich City   2  37  18.0  12.0   6.0  47.0  20.0  68.0    1.83
# 109    Southampton   2  37  21.0   8.0   8.0  37.0  31.0  71.0    1.91
# 153      Hull City   2  37  19.0   6.0  12.0  42.0   7.0  64.0    1.72
# 197        Burnley   2  37  21.0  12.0   4.0  30.0  28.0  75.0    2.02
# 241        Watford   2  37  22.0   6.0   9.0  40.0  33.0  72.0    1.93
# 285  Middlesbrough   2  37  21.0   9.0   7.0  25.0  26.0  72.0    1.93
# 329       Brighton   2  37  23.0   7.0   7.0  32.0  27.0  75.0    2.02
# 373   Cardiff City   2  37  22.0   7.0   8.0  31.0  24.0  72.0    1.96
# 417  Sheffield Utd   2  37  21.0   9.0   7.0  33.0  30.0  72.0    1.93

# %%
promoted_teams_37_avg = promoted_teams_37.mean()
promoted_teams_37_avg
# Out:
# <ipython-input-205-42b74eae099b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   promoted_teams_37_avg = promoted_teams_37.mean()
# Rk         2.000
# MP        37.000
# W         20.900
# D          8.600
# L          7.400
# GA        35.600
# GD        25.900
# Pts       71.400
# Pts/MP     1.923
# dtype: float64

# %%
merged_data.to_csv('merged_data.csv', index=False)

# %%
df_raiting = pd.read_csv('merged_data_2013_14-2019.csv')

# %%
df_raiting2 = pd.read_csv('df_rating3.csv')

# %%
df_raiting
# Out:
#       i            Squad  MP   W   D   L   GF  GA  GD  Pts  ...  Unnamed: 17  \
# 0     1  Manchester City  38  27   5   6  102  37  65   86  ...          NaN
# 1     2        Liverpool  38  26   6   6  101  50  51   84  ...          NaN
# 2     3          Chelsea  38  25   7   6   71  27  44   82  ...          NaN
# 3     4          Arsenal  38  24   7   7   68  41  27   79  ...          NaN
# 4     5          Everton  38  21   9   8   61  39  22   72  ...          NaN
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...  ...          ...
# 259  20          Reading  46  10  17  19   49  66 -17   47  ...          NaN
# 260  21         Millwall  46  10  14  22   48  64 -16   44  ...          NaN
# 261  22    Rotherham Utd  46   8  16  22   52  83 -31   40  ...          NaN
# 262  23           Bolton  46   8   8  30   29  78 -49   32  ...          NaN
# 263  24     Ipswich Town  46   5  16  25   36  77 -41   31  ...          NaN
#
# ...

# %%
df_raiting = df_raiting.drop(columns=['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'])

# %%
df_raiting2
# Out:
#                Squad  Shots Pg  Yellow   Red  Possession%  Pass%  AerialsWon  \
# 0          Liverpool      17.1       54    1         27.7   84.1        15.2
# 1    Manchester City      17.7       72    1         55.7   85.5        15.2
# 2            Chelsea      18.2       57    3         53.9   82.7        19.3
# 3            Arsenal      13.8       53    4         30.7   85.5        17.9
# 4            Everton      14.8       55    1         54.4   83.2        14.3
# ..               ...       ...      ...  ...          ...    ...         ...
# 259         Millwall      11.7       78    1         45.1   64.8        32.6
# 260        Rotherham      13.6       71    3         44.1   61.9        33.3
# 261            Wigan      12.6       91    4         47.8   69.9        26.7
# 262           Bolton       9.8       75    4         17.8   67.1        33.1
# 263          Ipswich       9.8       74    5         49.4   68.4        28.2
#
# ...

# %%
df_raiting
# Out:
#       i            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0     1  Manchester City  38  27   5   6  102  37  65   86    2.26
# 1     2        Liverpool  38  26   6   6  101  50  51   84    2.21
# 2     3          Chelsea  38  25   7   6   71  27  44   82    2.16
# 3     4          Arsenal  38  24   7   7   68  41  27   79    2.08
# 4     5          Everton  38  21   9   8   61  39  22   72    1.89
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 259  20          Reading  46  10  17  19   49  66 -17   47    1.02
# 260  21         Millwall  46  10  14  22   48  64 -16   44    0.96
# 261  22    Rotherham Utd  46   8  16  22   52  83 -31   40    0.87
# 262  23           Bolton  46   8   8  30   29  78 -49   32    0.70
# 263  24     Ipswich Town  46   5  16  25   36  77 -41   31    0.67
#
#      Attendance       Year League  Capacity  % Capacity Filled
# 0         47075    2013/14     PL     47805          98.472963
# ...

# %%
print(df_raiting.dtypes)
# Out:
# i                      int64
# Squad                 object
# MP                     int64
# W                      int64
# D                      int64
# L                      int64
# GF                     int64
# GA                     int64
# GD                     int64
# Pts                    int64
# Pts/MP               float64
# Attendance             int64
# Year                  object
# League                object
# Capacity               int64
# % Capacity Filled    float64
# dtype: object

# %%
print(df_raiting2.dtypes)
# Out:
# Squad           object
# Shots Pg       float64
# Yellow           int64
# Red              int64
# Possession%    float64
# Pass%          float64
# AerialsWon     float64
# Rating         float64
# Year            object
# League          object
# Unnamed: 10    float64
# Unnamed: 11    float64
# Unnamed: 12    float64
# Unnamed: 13    float64
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# dtype: object

# %%
df_raiting2['Squad'] = df_raiting2['Squad'].str.strip()

# %%
df_merged = pd.merge(df_raiting, df_raiting2, on=["Squad", "Year", "League"])

# %%
df_merged
# Out:
#       i            Squad  MP   W   D   L   GF  GA  GD  Pts  ...  Unnamed: 10  \
# 0     1  Manchester City  38  27   5   6  102  37  65   86  ...          NaN
# 1     2        Liverpool  38  26   6   6  101  50  51   84  ...          NaN
# 2     3          Chelsea  38  25   7   6   71  27  44   82  ...          NaN
# 3     4          Arsenal  38  24   7   7   68  41  27   79  ...          NaN
# 4     5          Everton  38  21   9   8   61  39  22   72  ...          NaN
# ..   ..              ...  ..  ..  ..  ..  ...  ..  ..  ...  ...          ...
# 140  14          Preston  46  16  13  17   67  67   0   61  ...          NaN
# 141  15        Blackburn  46  16  12  18   64  69  -5   60  ...          NaN
# 142  20          Reading  46  10  17  19   49  66 -17   47  ...          NaN
# 143  21         Millwall  46  10  14  22   48  64 -16   44  ...          NaN
# 144  23           Bolton  46   8   8  30   29  78 -49   32  ...          NaN
#
# ...

# %%
import numpy as np

# %%
pl_df = df_merged[df_merged['League']=='PL']
pl_avg_rating = pl_df['Rating'].mean()
print(pl_avg_rating)
# compute correlation matrix
corr_matrix = df_merged.corr()

# plot heatmap
plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap of df_merged with Annotation')
plt.show()
# Out:
# 6.837088607594935

# %%
# Select the relevant columns
cols = ['Pass%', 'Possession%', 'AerialsWon' ,'Shots Pg', 'Pts']
data = df_merged[cols]

# Calculate the correlation coefficients
corr = data.corr()

# Print the correlation matrix
print(corr)
# Out:
#                 Pass%  Possession%  AerialsWon  Shots Pg       Pts
# Pass%        1.000000     0.388369   -0.772635  0.595055  0.439055
# Possession%  0.388369     1.000000   -0.182415  0.237644  0.175845
# AerialsWon  -0.772635    -0.182415    1.000000 -0.415873 -0.214957
# Shots Pg     0.595055     0.237644   -0.415873  1.000000  0.708009
# Pts          0.439055     0.175845   -0.214957  0.708009  1.000000

# %%
# Calculate average points per year for each team
team_points = df_merged.groupby(['Squad'])['Pts'].mean().reset_index()

# Sort teams by average points
team_points = team_points.sort_values(by=['Pts'], ascending=False).reset_index(drop=True)

# Display top and bottom performing teams
print("Top performing teams:")
print(team_points.head())
print("\nBottom performing teams:")
print(team_points.tail())
# Out:
# Top performing teams:
#              Squad        Pts
# 0  Manchester City  84.500000
# 1        Liverpool  75.666667
# 2          Chelsea  75.666667
# 3        Tottenham  72.833333
# 4          Arsenal  72.400000
#
# Bottom performing teams:
#              Squad        Pts
# 23  Crystal Palace  44.833333
# 24       Doncaster  44.000000
# 25          Bolton  43.000000
# 26       Blackpool  36.000000
# 27      Sunderland  35.200000

# %%
# Compute the average team rating for each squad across all seasons
avg_ratings = df_raiting2.groupby("Squad")["Rating"].mean()

# Print out the top 5 and bottom 5 teams based on average rating
top_teams = avg_ratings.nlargest(5)
bottom_teams = avg_ratings.nsmallest(5)

print("Top 5 Teams:")
print(top_teams)
print("\nBottom 5 Teams:")
print(bottom_teams)
# Out:
# Top 5 Teams:
# Squad
# Manchester City    7.076667
# Arsenal            6.996667
# Liverpool          6.995000
# Chelsea            6.980000
# Tottenham          6.931667
# Name: Rating, dtype: float64
#
# Bottom 5 Teams:
# Squad
# Milton Keynes Dons    6.6300
# Burton                6.6650
# Huddersfield          6.6650
# Rotherham             6.6675
# Blackpool             6.6850
# Name: Rating, dtype: float64

# %%
# Calculate the average rating for each team across all years
team_avg = df_raiting2.groupby('Squad')['Rating'].mean().sort_values(ascending = False)

# Show the result
print(team_avg)
# Out:
# Squad
# Manchester City        7.076667
# Arsenal                6.996667
# Liverpool              6.995000
# Chelsea                6.980000
# Tottenham              6.931667
# Manchester United      6.913333
# Leicester              6.855000
# Derby                  6.845000
# Everton                6.843333
# Middlesbrough          6.836667
# Sheffield United       6.830000
# Yeovil                 6.820000
# Wolverhampton          6.818000
# Burnley                6.816667
# Brighton               6.810000
# Southampton            6.806667
# Brentford              6.804000
# Crystal Palace         6.803333
# West Ham               6.801667
# Nottingham Forest      6.800000
# Leeds                  6.796667
# Sheffield Wednesday    6.791667
# Blackburn              6.790000
# Barnsley               6.790000
# Bournemouth            6.778333
# Newcastle              6.778333
# Queens Park Rangers    6.776667
# Preston                6.775000
# Bristol City           6.775000
# ...

# %%
# filter the DataFrame to only include the rows where the league is "PL"
pl_df = df_raiting2[df_raiting2['League'] == 'PL']

# calculate the average rating for each squad
avg_ratings = pl_df.groupby('Squad')['Rating'].mean().sort_values(ascending=False)

# display the results
print(avg_ratings)
# Out:
# Squad
# Manchester City        7.076667
# Arsenal                6.996667
# Liverpool              6.995000
# Chelsea                6.980000
# Tottenham              6.931667
# Manchester United      6.913333
# Everton                6.843333
# Leicester              6.826000
# Southampton            6.806667
# Crystal Palace         6.803333
# West Ham               6.801667
# Stoke                  6.780000
# Queens Park Rangers    6.770000
# Newcastle              6.750000
# Wolverhampton          6.750000
# Burnley                6.747500
# Middlesbrough          6.740000
# Swansea                6.738000
# West Bromwich          6.712000
# Sunderland             6.702500
# Watford                6.697500
# Aston Villa            6.696667
# Bournemouth            6.695000
# Hull                   6.693333
# Brighton               6.650000
# Norwich                6.635000
# Cardiff                6.630000
# Fulham                 6.610000
# Huddersfield           6.540000
# ...

# %%
df_investment = pd.read_csv('Investment 2013-2019 pl2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-225-c607738d6a91> in <cell line: 1>()
# ----> 1 df_investment = pd.read_csv('Investment 2013-2019 pl2.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_investment

# %%
df_investment.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], axis=1, inplace=True)

# %%
df_investment

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace('FC','').str.strip()

# %%
df_investment["Squad"] = df_investment["Squad"].replace("AFC Bournemouth", "Bournemouth")

# %%
df_investment

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace(' City', '')
df_investment['Squad'] = df_investment['Squad'].replace('Manchester', 'Manchester City')

# %%
df_investment

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace(' United', '')
df_investment['Squad'] = df_investment['Squad'].replace('Manchester', 'Manchester United')

# %%
df_investment

# %%
df_investment['Squad'] = df_investment['Squad'].replace('Brighton & Hove Albion', 'Brighton')

# %%
df_investment["Squad"] = df_investment["Squad"].replace("A Bournemouth", "Bournemouth")

# %%
df_investment['Squad'] = df_investment['Squad'].replace('Sunderland A', 'Sunderland')

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace('Wolverhampton Wanderers', 'Wolverhampton')

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace('West Bromwich Albion', 'West Bromwich')

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace('Huddersfield Town', 'Huddersfield')

# %%
df_investment['Squad'] = df_investment['Squad'].str.replace('Tottenham Hotspur', 'Tottenham')

# %%
df_investment

# %%
avg_ratings

# %%
merged_df = pd.merge(avg_ratings, df_investment, on='Squad')

# %%
merged_df

# %%
print(merged_df["Investment"].dtype)

# %%
merged_df["Investment"] = merged_df["Investment"].str.replace("€", "")
merged_df["Investment"] = merged_df["Investment"].str.replace("bn", "000")
merged_df["Investment"] = merged_df["Investment"].str.replace("m", "")
merged_df["Investment"] = pd.to_numeric(merged_df["Investment"])
merged_df["Investment"] = merged_df["Investment"] / 1000

# %%
merged_df.loc[merged_df['Squad'] == 'Manchester City', 'Investment'] = 1.040

# %%
merged_df

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(merged_df["Investment"], merged_df["Rating"])

# Set the x-axis label
ax.set_xlabel("Investment (millions/1000 €)")

# Set the y-axis label
ax.set_ylabel("Team Performance Rating")

# Set the plot title
ax.set_title("Investment vs Rating in PL")

# Show the plot
plt.show()

# %%
df_investment2 = pd.read_csv('Investment 2013-19 CS.csv')

# %%
df_investment2

# %%
# filter the DataFrame to only include the rows where the league is "PL"
pl_df2 = df_raiting2[df_raiting2['League'] == 'CS']

# calculate the average rating for each squad
avg_ratings2 = pl_df2.groupby('Squad')['Rating'].mean().sort_values(ascending=False)

# display the results
print(avg_ratings2)

# %%
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' City', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' United', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' Town', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' Rovers', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' Athletic', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' FC', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' County', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' North End', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' Wanderers', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' Albion', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' & Hove Albion', '')
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' AFC', '')
df_investment2["Squad"] = df_investment2["Squad"].str.replace("AFC Bournemouth", "Bournemouth")
df_investment2['Squad'] = df_investment2['Squad'].str.replace(' & Hove', '')

# %%
df_investment2

# %%
df_investment2['Squad'] = df_investment2['Squad'].str.replace('Bristol', 'Bristol City')
df_investment2['Squad'] = df_investment2['Squad'].str.replace('Sheffield', 'Sheffield United')

# %%
merged_df2 = pd.merge(avg_ratings2, df_investment2, on='Squad')

# %%
merged_df2

# %%
merged_df2['Investment'] = merged_df2['Investment'].str.replace('€', '')

# %%
merged_df2['Investment'] = merged_df2['Investment'].str.replace('[km]$', '', regex=True)

# %%
merged_df2

# %%
merged_df2.loc[merged_df2['Squad'] == 'Milton Keynes Dons', 'Investment'] = '0.44'
merged_df2.loc[merged_df2['Squad'] == 'Doncaster', 'Investment'] = '0.175'

# %%
merged_df2

# %%
# Sort the DataFrame by the "Investment" column in descending order
cs_df = merged_df2[merged_df2['League'] == 'CS']
cs_df_sorted = cs_df.sort_values('Rating', ascending=False)

# Select the top 5 and bottom 5 rows
top_5 = cs_df_sorted.head(5)
bottom_5 = cs_df_sorted.tail(5)

# Print the results
print('Top 5 highest Rating clubs in CS with their Investment:')
print(top_5[['Squad', 'Rating', 'Investment']])
print('\n')
print('Top 5 lowest Rating clubs in CS with their Investment:')
print(bottom_5[['Squad', 'Rating', 'Investment']])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some example data
np.random.seed(40)
capacity_filled = np.random.normal(loc=50, scale=10, size=100)
performance_rating = capacity_filled * 0.3 + np.random.normal(loc=0, scale=10, size=100)

# Create a scatter plot
plt.scatter(capacity_filled, performance_rating)
plt.xlabel('Capacity Filled')
plt.ylabel('Performance Rating')
plt.title('Correlation of 0.3 between Capacity Filled and Performance Rating')
plt.show()
